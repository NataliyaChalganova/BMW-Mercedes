# %%
import pandas as pd

# %%
df = pd.read_csv ('T:\Data_Science\Practic\BI\mark.csv')
df.head(5)
# Out:
#                      Client ID                   Domain    City  Region  \
# 0  GA1.2.1029165320.1581675414       BMW-keyauto-krd.ru  Zurich  Zurich
# 1  GA1.2.1029165320.1581675414  cars.BMW-keyauto-krd.ru  Zurich  Zurich
# 2  GA1.2.1029165320.1581675414       BMW-keyauto-krd.ru  Zurich  Zurich
# 3   GA1.2.360702973.1573932024       BMW-keyauto-krd.ru  Zurich  Zurich
# 4  GA1.2.1394084210.1579796276    Mersedes-krasnodar.ru  Zurich  Zurich
#
#      Browser Device Category                Date  Pageviews   Campaign  \
# 0     Chrome          mobile  14 февраля 2020 г.         18  (not set)
# 1     Chrome          mobile  14 февраля 2020 г.          6  (not set)
# 2     Chrome          mobile  14 февраля 2020 г.         18  (not set)
# 3  YaBrowser          mobile   28 января 2020 г.          2  (not set)
# 4     Chrome          mobile   27 января 2020 г.          2  (not set)
#
#           Keyword  ...                   Source  Avg. Session Duration  \
# 0       (not set)  ...  cars.BMW-keyauto-krd.ru              0,0023
# 1       (not set)  ...       BMW-keyauto-krd.ru              0,0009
# 2       (not set)  ...  cars.BMW-keyauto-krd.ru              0,0023
# 3       (not set)  ...                yandex.ru                 -
# 4  (not provided)  ...                   google              0,0006
#
#    Bounce Rate Sessions          Goal Completion Location Goal Completions  \
# 0       -             1  /offers/buy/?trade_source=footer                1
# 1       -             2                                 /                1
# 2       -             1                                 /                1
# 3       -             1               /models/NewElantra/                0
# 4       -             2              /models/cla/options/                1
#
#    Goal Conversion Rate Goal Value Конверсия             Source conv.
# 0                  100%   38 039 ₽         1  cars.BMW-keyauto-krd.ru
# 1                   50%   17 971 ₽         1       BMW-keyauto-krd.ru
# 2                  100%   21 442 ₽         1  cars.BMW-keyauto-krd.ru
# 3                    0%        0 ₽         0                yandex.ru
# 4                   50%    8 498 ₽         1                   google
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Какие источники наиболее конвертируемые

# %%
df.groupby('Source')['Конверсия'].mean().sort_values(ascending=False)
# Out:
# Source
# crm2company.streamwood.ru    1.0
# alohafind.com                1.0
# tut.by                       1.0
# min.rusdealers.ru            1.0
# kuban.autoneva.ru            1.0
#                             ...
# bridgetsimon.top             0.0
# avto25.ru                    0.0
# auto.drom.ru                 0.0
# 192.168.8.1                  0.0
# честно-отзыв.рф              0.0
# Name: Конверсия, Length: 88, dtype: float64

# %% [markdown]
# ### Определите, какой источник трафика наиболее выгоден для компании по текущим данным

# %%
df.groupby('Source')['Sessions'].sum().sort_values(ascending=False)
# Out:
# Source
# google                       22432
# yandex.ru                    13665
# yandex                       11511
# BMW-keyauto-krd.ru           10654
# (direct)                     10390
#                              ...
# baidu.com                        1
# crm2company.streamwood.ru        1
# min.rusdealers.ru                1
# msk.autoneva.ru                  1
# m.vk.com                         1
# Name: Sessions, Length: 88, dtype: int64
